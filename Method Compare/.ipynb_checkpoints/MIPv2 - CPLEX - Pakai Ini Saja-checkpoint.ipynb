# %%
import os
os.environ["SPARK_HOME"] = "D:\RISET\Spark\spark-3.1.1-bin-hadoop2.7"
from platform import python_version
print(python_version())
# Out:
# 3.7.10

# %%
import numpy as np
import pandas as pd
import xlwings as xw
import folium
import docplex.mp.solution as mp_sol
from docplex.mp.model import Model
from geopy.distance import great_circle
import json

n = 50
customer = [i for i in range(1, n + 1)]
customer2 = [i for i in range(1, n + 1)]
node = [0] + customer
arcos = [(i,j) for i in node for j in node if i != j]
f = open('pelanggan4.json')
data = json.load(f)

# get customer demand and location data
df = pd.DataFrame(data)

# get distance & duration data
distance = np.loadtxt('distance.txt')
duration = np.loadtxt('duration.txt')
vehicle_capacity = 250

# Start time
e = [df['ready_time'][i] for i in range(n + 1)]
e[0] = 0

# Due time
l = [df['due_time'][i] for i in range(n + 1)]
 

# Service time
ser = [df['service_time'][i] for i in range(n + 1)]
ser[0] = 0

M = 5000  # big number
no_of_vehicles = 3  # free to modify
n = n + 1

# %%
mdl = Model('CVRPTW')
x = mdl.binary_var_dict(arcos, name='x')
u = mdl.continuous_var_dict(customer, name='u')
t = mdl.continuous_var_dict(customer2, name='t')

# %%
mdl.add_constraints(mdl.sum(x[(i,j)] for i,j in arcos if i==h)== 1 for h in customer)# vehicles leaving each customer node
mdl.add_constraints(mdl.sum(x[(i,j)] for i,j in arcos if j==h)== 1 for h in customer)# vehicles arriving to each customer node
# mdl.add_constraint(mdl.sum(x[(0,j)] for j in customer) == no_of_vehicles)# vehicles leaving depot
# mdl.add_constraint(mdl.sum(x[(i,0)] for i in customer) == no_of_vehicles)# vehicles arriving to depot
# Out:
# [docplex.mp.LinearConstraint[](x_0_1+x_2_1+x_3_1+x_4_1+x_5_1+x_6_1+x_7_1+x_8_1+x_9_1+x_10_1+x_11_1+x_12_1+x_13_1+x_14_1+x_15_1+x_16_1+x_17_1+x_18_1+x_19_1+x_20_1+x_21_1+x_22_1+x_23_1+x_24_1+x_25_1+x_26_1+x_27_1+x_28_1+x_29_1+x_30_1+x_31_1+x_32_1+x_33_1+x_34_1+x_35_1,EQ,1),
#  docplex.mp.LinearConstraint[](x_0_2+x_1_2+x_3_2+x_4_2+x_5_2+x_6_2+x_7_2+x_8_2+x_9_2+x_10_2+x_11_2+x_12_2+x_13_2+x_14_2+x_15_2+x_16_2+x_17_2+x_18_2+x_19_2+x_20_2+x_21_2+x_22_2+x_23_2+x_24_2+x_25_2+x_26_2+x_27_2+x_28_2+x_29_2+x_30_2+x_31_2+x_32_2+x_33_2+x_34_2+x_35_2,EQ,1),
#  docplex.mp.LinearConstraint[](x_0_3+x_1_3+x_2_3+x_4_3+x_5_3+x_6_3+x_7_3+x_8_3+x_9_3+x_10_3+x_11_3+x_12_3+x_13_3+x_14_3+x_15_3+x_16_3+x_17_3+x_18_3+x_19_3+x_20_3+x_21_3+x_22_3+x_23_3+x_24_3+x_25_3+x_26_3+x_27_3+x_28_3+x_29_3+x_30_3+x_31_3+x_32_3+x_33_3+x_34_3+x_35_3,EQ,1),
            # taking the linear distance from one node to other as travelling time in minutes between those nodes
            mdl.add_indicator(x[(i,j)], t[i] + ser[i] + duration[i][j] <= t[j])

# %%
'''constraint_5: capacity of vehicle and also eliminating sub-tours'''
for j in customer:
    mdl.add_constraint(u[j] <= vehicle_capacity)
    mdl.add_constraint(u[j] >= df.demand[j])
    for i in customer:
        if i!= j:
            mdl.add_constraint(u[j] >= u[i] + df.demand[j] * (x[i,j]) - vehicle_capacity * (1 - (x[i,j])))

# %%
'''objective function'''
mdl.minimize(mdl.sum(distance[(i, j)] * x[(i, j)] for i, j in arcos))

# %%
mdl.parameters.timelimit = 60
# mdl.parameters.parallel = 1
# mdl.parameters.threads =  0
# mdl.parameters.benders.strategy = -1
# mdl.parameters.mip.limits.cutsfactor = 0
# mdl.parameters.mip.tolerances.mipgap = 0.1
# mdl.parameters.mip.strategy.branch = 0

###Menghitung Waktu
import time
start_timer = time.time()

solucion = mdl.solve(log_output=True)

###Menghitung Waktu
done_timer = time.time()
elapsed = done_timer - start_timer
# Out:
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_TimeLimit                               60
# Found incumbent of value 202988.000000 after 0.00 sec. (0.15 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 324 rows and 184 columns.
# MIP Presolve modified 2423 coefficients.
# Aggregator did 411 substitutions.
# Reduced MIP has 2677 rows, 1741 columns, and 8897 nonzeros.
# Reduced MIP has 1076 binaries, 0 generals, 0 SOSs, and 1006 indicators.
# Presolve time = 0.03 sec. (9.50 ticks)
# Probing time = 0.05 sec. (19.49 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 2677 rows, 1741 columns, and 8897 nonzeros.
# Reduced MIP has 1076 binaries, 0 generals, 0 SOSs, and 1006 indicators.
# Presolve time = 0.00 sec. (5.80 ticks)
# Probing time = 0.02 sec. (3.33 ticks)
# Clique table members: 5680.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.06 sec. (12.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       202988.0000        0.0000           100.00%
# *     0+    0                       200673.0000        0.0000           100.00%
#       0     0    38043.8630    57   200673.0000    38043.8630      189   81.04%
# *     0+    0                       136981.0000    38043.8630            72.23%
# *     0+    0                        76617.0000    38043.8630            50.35%
#       0     0    42112.3991    57    76617.0000     Cuts: 493      479   45.04%
#       0     0    42899.9968    57    76617.0000     Cuts: 421      715   44.01%
#       0     0    43213.8110    57    76617.0000     Cuts: 447      878   43.60%
#       0     0    43478.4934    57    76617.0000     Cuts: 230      964   43.25%
#       0     0    43541.9786    57    76617.0000      Cuts: 92     1036   43.17%
# Detecting symmetries...
#       0     0    43667.7293    57    76617.0000     Cuts: 127     1251   43.01%
#       0     0    43859.4635    57    76617.0000     Cuts: 190     1452   42.75%
#       0     0    43928.1026    57    76617.0000     Cuts: 381     1570   42.67%
#       0     0    44011.6622    57    76617.0000     Cuts: 191     1657   42.56%
#       0     0    44056.6108    57    76617.0000     Cuts: 182     1724   42.50%
#       0     0    44142.2371    57    76617.0000      Cuts: 83     1795   42.39%
#       0     0    44211.8361    57    76617.0000     Cuts: 106     1885   42.30%
#       0     0    44296.6713    57    76617.0000     Cuts: 189     1960   42.18%
#       0     0    44396.0303    57    76617.0000     Cuts: 187     2086   42.05%
# *     0+    0                        74703.0000    44396.0303            40.57%
#       0     0    44534.8308    57    74703.0000     Cuts: 328     2202   40.38%
#       0     0    44636.5215    57    74703.0000      Cuts: 58     2301   40.25%
#       0     0    44932.7487    57    74703.0000     Cuts: 246     2470   39.85%
#       0     0    45060.6358    57    74703.0000     Cuts: 207     2750   39.68%
#       0     0    45096.5724    57    74703.0000     Cuts: 480     2912   39.63%
#       0     0    45101.0314    57    74703.0000     Cuts: 259     2977   39.63%
#       0     0    45152.3068    57    74703.0000     Cuts: 159     3144   39.56%
#       0     0    45200.3254    57    74703.0000     Cuts: 266     3309   39.49%
#       0     0    45257.0855    57    74703.0000     Cuts: 244     3548   39.42%
#       0     0    45303.2679    57    74703.0000     Cuts: 349     3660   39.36%
#       0     0    45387.9787    57    74703.0000     Cuts: 187     3895   39.24%
#       0     0    45479.5117    57    74703.0000     Cuts: 769     4181   39.12%
#       0     0    45519.1789    57    74703.0000     Cuts: 331     4297   39.07%
#       0     0    45528.9000    57    74703.0000     Cuts: 203     4381   39.05%
# *     0+    0                        73466.0000    45528.9000            38.03%
# Detecting symmetries...
#       0     2    45528.9000   107    73466.0000    45528.9000     4381   38.03%
# Elapsed time = 3.55 sec. (1428.04 ticks, tree = 0.02 MB, solutions = 6)
# *    10+    3                        73362.0000    45531.0000            37.94%
#      98    85    56883.5918    42    73362.0000    45635.7828    16028   37.79%
#     306   283    65683.1150    31    73362.0000    45635.7828    36106   37.79%
# *   424+  292                        69571.0000    45635.7828            34.40%
# *   427+  292                        69570.0000    45635.7828            34.40%
#     538   455    56317.9871    55    69570.0000    45635.7828    51139   34.40%
#     882   760    66859.4707    22    69570.0000    45635.7828    72409   34.40%
#    1135   910    56562.3910    56    69570.0000    45851.5500    88668   34.09%
#    1339  1165    54884.6662    53    69570.0000    45851.5500   114695   34.09%
#    1656  1466    46820.6570    88    69570.0000    45851.5500   140029   34.09%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# Reduced MIP has 2677 rows, 1741 columns, and 8897 nonzeros.
# Reduced MIP has 1076 binaries, 0 generals, 0 SOSs, and 1006 indicators.
# Presolve time = 0.00 sec. (4.63 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2677 rows, 1741 columns, and 8897 nonzeros.
# Reduced MIP has 1076 binaries, 0 generals, 0 SOSs, and 1006 indicators.
# Presolve time = 0.02 sec. (6.13 ticks)
# Represolve time = 0.09 sec. (42.06 ticks)
#    1736     0    45642.8805   110    69570.0000     Cuts: 112   151945   34.09%
#    1736     0    45757.6486   110    69570.0000     Cuts: 117   152116   34.09%
#    1736     0    45841.8761   110    69570.0000     Cuts: 241   152227   34.09%
#    1736     0    45872.8891   110    69570.0000     Cuts: 160   152504   34.06%
#    1736     0    46065.1205   110    69570.0000     Cuts: 181   152873   33.79%
#    1736     0    46175.7881   110    69570.0000     Cuts: 242   153040   33.63%
#    1736     0    46198.6013   110    69570.0000     Cuts: 103   153149   33.59%
#    1736     0    46215.0311   110    69570.0000      Cuts: 96   153197   33.57%
#    1736     0    46286.0810   110    69570.0000      Cuts: 30   153373   33.47%
#    1736     0    46362.4788   110    69570.0000     Cuts: 112   153569   33.36%
#    1736     0    46376.1210   110    69570.0000     Cuts: 116   153676   33.34%
#    1736     0    46419.3876   110    69570.0000     Cuts: 155   153768   33.28%
#    1736     0    46420.6384   110    69570.0000     Cuts: 161   153857   33.27%
#    1736     0    46450.0923   110    69570.0000     Cuts: 184   153922   33.23%
#    1736     0    46470.2890   110    69570.0000      Cuts: 85   153991   33.20%
#    1736     0    46491.7628   110    69570.0000      Cuts: 72   154075   33.17%
#    1736     0    46508.1674   110    69570.0000      Cuts: 81   154136   33.15%
#    1736     0    46524.3944   110    69570.0000      Cuts: 93   154191   33.13%
#    1736     0    46526.4252   110    69570.0000      Cuts: 46   154217   33.12%
#    1736     0    46526.5967   110    69570.0000       Cuts: 6   154223   33.12%
#    1736     0    46544.2514   110    69570.0000     Cuts: 126   154288   33.10%
#    1736     0    46545.1172   110    69570.0000      Cuts: 44   154315   33.10%
#    1736     2    46545.1172   132    69570.0000    46545.1172   154315   33.10%
#    1737     3    46567.3671   122    69570.0000    46570.2591   154446   33.06%
#    1830    45    55387.3462    91    69570.0000    46655.5641   164214   32.94%
# Elapsed time = 29.17 sec. (13528.82 ticks, tree = 0.32 MB, solutions = 9)
#    2192   373    57427.4975    74    69570.0000    46655.5641   196129   32.94%
#    2929   988    48052.7876    86    69570.0000    46655.5641   216343   32.94%
#    3898  1827    62597.3387    71    69570.0000    46655.5641   245279   32.94%
#    4772  2637    49520.1881    99    69570.0000    46850.5224   274396   32.66%
#    6160  3935    52471.0536    91    69570.0000    46963.1979   318517   32.50%
#    7579  5157    53610.9948    81    69570.0000    47044.6826   353257   32.38%
#    8720  6386    55050.4245    76    69570.0000    47123.4262   397013   32.26%
#   10043  7669    58961.7602    69    69570.0000    47206.5916   438802   32.15%
#   11054  8713    54526.5988    73    69570.0000    47221.6923   463962   32.12%
#   12468  9899    54073.5611    93    69570.0000    47296.0933   503843   32.02%
# Elapsed time = 50.03 sec. (23075.45 ticks, tree = 187.04 MB, solutions = 9)
#   13652 11306    65843.5880    58    69570.0000    47305.9733   550857   32.00%
# Starting limited solution polishing.
#   15080 12461    56323.2537    75    69570.0000    47333.1175   589641   31.96%
#   15911 13376    61382.7698    67    69570.0000    47377.6196   634886   31.90%
# * 15914+13313                        69345.0000    47377.6196            31.68%
#   17299 14665    55312.5300    76    69345.0000    47406.7838   680070   31.64%
#
# GUB cover cuts applied:  19
# Clique cuts applied:  77
# Cover cuts applied:  20
# Implied bound cuts applied:  21
# Flow cuts applied:  27
# Mixed integer rounding cuts applied:  174
# Zero-half cuts applied:  63
# Multi commodity flow cuts applied:  2
# Lift and project cuts applied:  48
# Gomory fractional cuts applied:  2
#
# Root node processing (before b&c):
#   Real time             =    3.50 sec. (1412.04 ticks)
# Parallel b&c, 8 threads:
#   Real time             =   56.53 sec. (25947.75 ticks)
#   Sync time (average)   =    7.38 sec.
#   Wait time (average)   =    0.04 sec.
#                           ------------
# Total (root+branch&cut) =   60.03 sec. (27359.78 ticks)

# %%
mdl.get_solve_status()
# Out:
# <JobSolveStatus.FEASIBLE_SOLUTION: 1>

# %%
# Encontrar las rutas por separado
route = []
total_dis = []
for h in customer:
    if x[(0, h)].solution_value > 0.9:
        arcos_route = [(0, h)]
        item_dis = distance[0][h]
        j = h
        while j!=0:
            i = j
            for k in node:
                if i!=k and x[(i, k)].solution_value > 0.9:
                    j = k
                    arcos_route.append((i, j))
                    item_dis+= distance[i][j]
                    break
        route.append(arcos_route)
        print(arcos_route)
        print("----------------------")
        total_dis.append(item_dis)
# Out:
# [(0, 6), (6, 22), (22, 11), (11, 0)]
# ----------------------
# [(0, 7), (7, 5), (5, 15), (15, 14), (14, 13), (13, 26), (26, 0)]
# ----------------------
# [(0, 9), (9, 1), (1, 2), (2, 24), (24, 0)]
# ----------------------
# [(0, 10), (10, 23), (23, 27), (27, 34), (34, 21), (21, 0)]
# ----------------------
# [(0, 12), (12, 32), (32, 28), (28, 33), (33, 25), (25, 0)]
# ----------------------
# [(0, 18), (18, 19), (19, 20), (20, 4), (4, 8), (8, 0)]
# ----------------------
# [(0, 29), (29, 30), (30, 31), (31, 0)]
# ----------------------
# [(0, 35), (35, 16), (16, 17), (17, 3), (3, 0)]
# ----------------------

# %%
best_distance = 0
for n in range(len(route)):
    print("Rute "+str(n))
    print(str(route[n])+" -> "+str(total_dis[n]))
    best_distance+=total_dis[n]
print("Total Distace : "+str(best_distance))
print(elapsed)
# Out:
# Rute 0
# [(0, 6), (6, 22), (22, 11), (11, 0)] -> 4807.0
# Rute 1
# [(0, 7), (7, 5), (5, 15), (15, 14), (14, 13), (13, 26), (26, 0)] -> 10539.0
# Rute 2
# [(0, 9), (9, 1), (1, 2), (2, 24), (24, 0)] -> 5798.0
# Rute 3
# [(0, 10), (10, 23), (23, 27), (27, 34), (34, 21), (21, 0)] -> 4037.0
# Rute 4
# [(0, 12), (12, 32), (32, 28), (28, 33), (33, 25), (25, 0)] -> 13260.0
# Rute 5
# [(0, 18), (18, 19), (19, 20), (20, 4), (4, 8), (8, 0)] -> 9019.0
# Rute 6
# [(0, 29), (29, 30), (30, 31), (31, 0)] -> 10181.0
# Rute 7
# [(0, 35), (35, 16), (16, 17), (17, 3), (3, 0)] -> 11704.0
# Total Distace : 69345.0
# 60.064138889312744

# %%
best_distance = 0
for n in range(len(route)):
    print("Rute "+str(n))
    print(str(route[n])+" -> "+str(total_dis[n]))
    s_time = 0
    demands = 0
    for rt in route[n]:
        (i,j) = rt
        demands+=df.demand[j]
        s_time += duration[i][j]
        print(str(rt)+" --> "+str(e[j])+" - "+str(l[j])+" --> "+str(s_time))
        s_time += ser[j]
    print("Total Demands : "+str(demands))
    print("----------")
    best_distance+=total_dis[n]
print("Total Distace : "+str(best_distance))

print(elapsed)
# Out:
# Rute 0
# [(0, 6), (6, 22), (22, 11), (11, 0)] -> 4807.0
# (0, 6) --> 810 - 2010 --> 382.0
# (6, 22) --> 245 - 1445 --> 740.0
# (22, 11) --> 1078 - 2278 --> 1174.0
# (11, 0) --> 0 - 5000 --> 1581.0
# Total Demands : 138
# ----------
# Rute 1
# [(0, 7), (7, 5), (5, 15), (15, 14), (14, 13), (13, 26), (26, 0)] -> 10539.0
# (0, 7) --> 219 - 1419 --> 531.0
# (7, 5) --> 325 - 1525 --> 1020.0
# (5, 15) --> 576 - 1776 --> 1389.0
# (15, 14) --> 1018 - 2218 --> 1672.0
# (14, 13) --> 687 - 1887 --> 1978.0
# (13, 26) --> 958 - 2158 --> 2409.0
# (26, 0) --> 0 - 5000 --> 2917.0
# Total Demands : 137
# ----------
# Rute 2
# [(0, 9), (9, 1), (1, 2), (2, 24), (24, 0)] -> 5798.0
# (0, 9) --> 605 - 1805 --> 407.0
# (9, 1) --> 987 - 2187 --> 764.0
# (1, 2) --> 367 - 1567 --> 1039.0
# (2, 24) --> 1151 - 2351 --> 1317.0
# (24, 0) --> 0 - 5000 --> 1855.0
# Total Demands : 189
# ----------
# Rute 3
# [(0, 10), (10, 23), (23, 27), (27, 34), (34, 21), (21, 0)] -> 4037.0
# (0, 10) --> 117 - 1317 --> 266.0
# (10, 23) --> 736 - 1936 --> 631.0
# (23, 27) --> 696 - 1896 --> 888.0
# (27, 34) --> 243 - 1443 --> 1132.0
# (34, 21) --> 1173 - 2373 --> 1531.0
# (21, 0) --> 0 - 5000 --> 1888.0
# Total Demands : 166
# ----------
# Rute 4
# [(0, 12), (12, 32), (32, 28), (28, 33), (33, 25), (25, 0)] -> 13260.0
# (0, 12) --> 140 - 1340 --> 377.0
# (12, 32) --> 151 - 1351 --> 725.0
# (32, 28) --> 154 - 1354 --> 1087.0
# (28, 33) --> 263 - 1463 --> 1687.0
# (33, 25) --> 1028 - 2228 --> 2280.0
# (25, 0) --> 0 - 5000 --> 2877.0
# Total Demands : 217
# ----------
# Rute 5
# [(0, 18), (18, 19), (19, 20), (20, 4), (4, 8), (8, 0)] -> 9019.0
# (0, 18) --> 222 - 1422 --> 497.0
# (18, 19) --> 333 - 1533 --> 764.0
# (19, 20) --> 914 - 2114 --> 1100.0
# (20, 4) --> 202 - 1402 --> 1563.0
# (4, 8) --> 860 - 2060 --> 1863.0
# (8, 0) --> 0 - 5000 --> 2610.0
# Total Demands : 167
# ----------
# Rute 6
# [(0, 29), (29, 30), (30, 31), (31, 0)] -> 10181.0
# (0, 29) --> 1027 - 2227 --> 550.0
# (29, 30) --> 580 - 1780 --> 1279.0
# (30, 31) --> 1131 - 2331 --> 1594.0
# (31, 0) --> 0 - 5000 --> 2178.0
# Total Demands : 112
# ----------
# Rute 7
# [(0, 35), (35, 16), (16, 17), (17, 3), (3, 0)] -> 11704.0
# (0, 35) --> 270 - 1470 --> 623.0
# (35, 16) --> 729 - 1929 --> 1245.0
# (16, 17) --> 959 - 2159 --> 1535.0
# (17, 3) --> 1129 - 2329 --> 2037.0
# (3, 0) --> 0 - 5000 --> 2752.0
# Total Demands : 132
# ----------
# Total Distace : 69345.0
# 60.064138889312744
